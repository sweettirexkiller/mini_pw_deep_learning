# %% [markdown]
# 1. Instalacja zależności

# %%
pip install -q transformers accelerate bitsandbytes
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
import torch, requests, io
import numpy as np
import matplotlib.pyplot as plt
import polars as pl
from transformers import pipeline
# Out:
# /Users/piotrjankiewicz/Documents/PROJEKTY/PW/DeepLearning/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
if torch.backends.cuda.is_built():
  device = torch.device("cuda")
else:
  device = torch.device("cpu")

if torch.backends.mps.is_available():
    print("MPS backend is available.")
    device = torch.device("mps")


print(device)
# Out:
# MPS backend is available.
# mps

# %%
# !wget https://huggingface.co/datasets/wikimedia/wit_base/resolve/main/data/train-00000-of-00330.parquet
# Out:
# --2025-06-12 15:05:19--  https://huggingface.co/datasets/wikimedia/wit_base/resolve/main/data/train-00000-of-00330.parquet
# Resolving huggingface.co (huggingface.co)... 65.9.95.31, 65.9.95.114, 65.9.95.73, ...
# Connecting to huggingface.co (huggingface.co)|65.9.95.31|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.hf.co/repos/e2/d7/e2d7a26d244e74b03e3e206b9fa071a324113e96dc2ecf918015ce67540fb780/8a9a449a0db937920b7c0dd13cd0bc9b1cadb19071567169dbac41a956273ec2?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27train-00000-of-00330.parquet%3B+filename%3D%22train-00000-of-00330.parquet%22%3B&Expires=1749737120&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=VoMcpvtri1KcRSXj6Rwh683DIOi4cPmiEisx2Z143KYr6aLCIlkgNtRBW96wvMZ--cxiFsCmUi6%7EYqAcLxkgmaMgdtBToISGIWdah7d9sm-SLZCrvKIdEmclWm9Nyqsh1VNADYtU3hVVhcGpQtsAGrJcF6Zokh-a%7EALCrnTdMC4W6OyjOO7DFBXgo%7EFZbYcP01afRkutffBQbG%7EjHwNaU%7EG58PowZA-Xv3HYUnZyO4I%7Ejv17RGZR49gCpkEdy0akcH6-oqc46R9hlOV0yuAVYYUadA8k86DtbG2HJXBecerr1c5R2OQd0BzrEtC7ebLrwXsPPBkI-%7EQCr4fcrTgCUw__&Key-Pair-Id=K3RPWS32NSSJCE [following]
# --2025-06-12 15:05:20--  https://cdn-lfs.hf.co/repos/e2/d7/e2d7a26d244e74b03e3e206b9fa071a324113e96dc2ecf918015ce67540fb780/8a9a449a0db937920b7c0dd13cd0bc9b1cadb19071567169dbac41a956273ec2?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27train-00000-of-00330.parquet%3B+filename%3D%22train-00000-of-00330.parquet%22%3B&Expires=1749737120&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=VoMcpvtri1KcRSXj6Rwh683DIOi4cPmiEisx2Z143KYr6aLCIlkgNtRBW96wvMZ--cxiFsCmUi6%7EYqAcLxkgmaMgdtBToISGIWdah7d9sm-SLZCrvKIdEmclWm9Nyqsh1VNADYtU3hVVhcGpQtsAGrJcF6Zokh-a%7EALCrnTdMC4W6OyjOO7DFBXgo%7EFZbYcP01afRkutffBQbG%7EjHwNaU%7EG58PowZA-Xv3HYUnZyO4I%7Ejv17RGZR49gCpkEdy0akcH6-oqc46R9hlOV0yuAVYYUadA8k86DtbG2HJXBecerr1c5R2OQd0BzrEtC7ebLrwXsPPBkI-%7EQCr4fcrTgCUw__&Key-Pair-Id=K3RPWS32NSSJCE
# Resolving cdn-lfs.hf.co (cdn-lfs.hf.co)... 65.9.95.41, 65.9.95.116, 65.9.95.126, ...
# Connecting to cdn-lfs.hf.co (cdn-lfs.hf.co)|65.9.95.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 932699916 (889M) [binary/octet-stream]
# Saving to: ‘train-00000-of-00330.parquet’
#
# train-00000-of-0033 100%[===================>] 889.49M  22.9MB/s    in 28s
#
# 2025-06-12 15:05:48 (32.2 MB/s) - ‘train-00000-of-00330.parquet’ saved [932699916/932699916]

# %%
# !ls
# Out:
# data_prep.ipynb              train-00000-of-00330.parquet
